# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.patches import Patch

# %%
lsoa_supply = pd.read_csv("Data/Output/lsoa_supply.csv")
lsoa_demand = gpd.read_file("Data/Output/lsoa_demand.shp")
lsoa = gpd.read_file("Data/manchester_lsoa/manchester_lsoa.shp")
lsoa_outline = gpd.read_file("Data/manchester_lsoa/manchester_outline.shp")

# %%
msoa_demand
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 msoa_demand
#
# NameError: name 'msoa_demand' is not defined

# %%
msoa_demand.info()

# %%
msoa_demand["pop_density_norm"] = msoa_demand["pop_density"] / msoa_demand["pop_density"].max()
msoa_demand.pop_density_norm

print(msoa_demand.pop_density_norm.max())
print(msoa_demand.pop_density_norm.min())

# %%
msoa_demand["Elderly Percentage_norm"] = msoa_demand["Elderly Percentage"] / msoa_demand["Elderly Percentage"].max()
msoa_demand["Elderly Percentage_norm"]

print(msoa_demand["Elderly Percentage_norm"].max())
print(msoa_demand["Elderly Percentage_norm"].min())

# %%
msoa_demand["Children Percentage_norm"] = msoa_demand["Children Percentage"] / msoa_demand["Children Percentage"].max()
msoa_demand["Children Percentage_norm"]

print(msoa_demand["Children Percentage_norm"].max())
print(msoa_demand["Children Percentage_norm"].min())

# %%
msoa_demand["Total annual income_norm"] = msoa_demand["Total annual income"] / msoa_demand["Total annual income"].max()
msoa_demand["Total annual income_norm"]

print(msoa_demand["Total annual income_norm"].max())
print(msoa_demand["Total annual income_norm"].min())

# %%
msoa_demand["Disabled-No Car Household_norm"] = msoa_demand["Disabled-No Car Household"] / msoa_demand["Disabled-No Car Household"].max()
msoa_demand["Disabled-No Car Household_norm"]

print(msoa_demand["Disabled-No Car Household_norm"].max())
print(msoa_demand["Disabled-No Car Household_norm"].min())

# %%
msoa_demand

# %%
n_var = 5 ## Number of variables considered in the index
msoa_demand["pt_demand"] = (msoa_demand["pop_density_norm"] + msoa_demand["Elderly Percentage_norm"] + msoa_demand["Children Percentage_norm"] + msoa_demand["Total annual income_norm"] + msoa_demand["Disabled-No Car Household_norm"]) / n_var

# %%
msoa_demand

# %% [markdown]
# ## LSOA Supply

# %%
lsoa_supply
# Out:
#       Unnamed: 0   lsoa21cd        lsoa21nm  \
# 0              0  E01004901     Bolton 028E
# 1              1  E01005001       Bury 012B
# 2              2  E01004840     Bolton 012A
# 3              3  E01005006       Bury 012D
# 4              4  E01004773     Bolton 003D
# ...          ...        ...             ...
# 1697        1697  E01006410      Wigan 020E
# 1698        1698  E01006400      Wigan 021D
# 1699        1699  E01006331      Wigan 031D
# 1700        1700  E01006397      Wigan 011C
# 1701        1701  E01005866  Stockport 006C
#
#                                                geometry  area_sqkm  \
# 0     POLYGON ((366003.09300000034 406666.6879999991...   0.354363
# 1     POLYGON ((375480.34800000023 408593.1229999997...   0.238302
# 2     POLYGON ((367374.7810000004 411954.5940000005,...   4.181101
# 3     POLYGON ((377212.6880000001 410849.5, 377231.9...   1.772635
# 4     POLYGON ((371776.55900000036 412463.2035000007...   0.266227
# ...                                                 ...        ...
# 1697  POLYGON ((357596.9539999999 403017.37549999915...   0.628715
# 1698  POLYGON ((356213.7599999998 403792.3969999999,...   0.569408
# 1699  POLYGON ((367336.96999999974 401009.4519999996...   0.596520
# 1700  POLYGON ((354859.3119999999 406046.90399999917...   0.147755
# 1701  POLYGON ((388072.36649999954 392494.4039999991...   0.288469
#
#       bus_stops_count  bus_stops_density  nearest_station_distance
# 0                   4          11.287876                583.787237
# 1                   4          16.785438               2682.823140
# 2                  25           5.979287               2153.166001
# 3                  26          14.667433               2828.181650
# 4                   9          33.805782               1467.288813
# ...               ...                ...                       ...
# 1697                8          12.724362               2090.861678
# 1698                1           1.756210                588.128763
# 1699                6          10.058336               3640.594673
# 1700                4          27.071827               1516.597364
# 1701               16          55.465277                255.325137
#
# [1702 rows x 8 columns]

# %%
lsoa_supply = lsoa_supply.rename(columns={"Unnamed: 0" : "n_lsoa"})

# %%
lsoa_supply["nearest_station_distance_norm"] = lsoa_supply["nearest_station_distance"] / lsoa_supply["nearest_station_distance"].max()
lsoa_supply["nearest_station_distance_norm"]

print(lsoa_supply.nearest_station_distance_norm.max())
print(lsoa_supply.nearest_station_distance_norm.min())
# Out:
# 1.0
# 0.0018451726144325803

# %%
lsoa_supply["bus_stops_density_norm"] = lsoa_supply["bus_stops_density"] / lsoa_supply["bus_stops_density"].max()
lsoa_supply["bus_stops_density_norm"]

print(lsoa_supply.bus_stops_density_norm.max())
print(lsoa_supply.bus_stops_density_norm.min())
# Out:
# 1.0
# 0.0013623890507286642

# %%
lsoa_supply
# Out:
#       n_lsoa   lsoa21cd        lsoa21nm  \
# 0          0  E01004901     Bolton 028E
# 1          1  E01005001       Bury 012B
# 2          2  E01004840     Bolton 012A
# 3          3  E01005006       Bury 012D
# 4          4  E01004773     Bolton 003D
# ...      ...        ...             ...
# 1697    1697  E01006410      Wigan 020E
# 1698    1698  E01006400      Wigan 021D
# 1699    1699  E01006331      Wigan 031D
# 1700    1700  E01006397      Wigan 011C
# 1701    1701  E01005866  Stockport 006C
#
#                                                geometry  area_sqkm  \
# 0     POLYGON ((366003.09300000034 406666.6879999991...   0.354363
# 1     POLYGON ((375480.34800000023 408593.1229999997...   0.238302
# 2     POLYGON ((367374.7810000004 411954.5940000005,...   4.181101
# 3     POLYGON ((377212.6880000001 410849.5, 377231.9...   1.772635
# 4     POLYGON ((371776.55900000036 412463.2035000007...   0.266227
# ...                                                 ...        ...
# 1697  POLYGON ((357596.9539999999 403017.37549999915...   0.628715
# 1698  POLYGON ((356213.7599999998 403792.3969999999,...   0.569408
# 1699  POLYGON ((367336.96999999974 401009.4519999996...   0.596520
# 1700  POLYGON ((354859.3119999999 406046.90399999917...   0.147755
# 1701  POLYGON ((388072.36649999954 392494.4039999991...   0.288469
#
#       bus_stops_count  bus_stops_density  nearest_station_distance  \
# 0                   4          11.287876                583.787237
# 1                   4          16.785438               2682.823140
# 2                  25           5.979287               2153.166001
# 3                  26          14.667433               2828.181650
# 4                   9          33.805782               1467.288813
# ...               ...                ...                       ...
# 1697                8          12.724362               2090.861678
# 1698                1           1.756210                588.128763
# 1699                6          10.058336               3640.594673
# 1700                4          27.071827               1516.597364
# 1701               16          55.465277                255.325137
#
#       nearest_station_distance_norm  bus_stops_density_norm
# 0                          0.081805                0.030128
# 1                          0.375938                0.044801
# 2                          0.301719                0.015959
# 3                          0.396307                0.039148
# 4                          0.205608                0.090228
# ...                             ...                     ...
# 1697                       0.292988                0.033962
# 1698                       0.082413                0.004687
# 1699                       0.510149                0.026846
# 1700                       0.212518                0.072255
# 1701                       0.035778                0.148038
#
# [1702 rows x 10 columns]

# %%
n_supply = 2 ## Number of variables considered in the index
lsoa_supply["pt_supply"] = (lsoa_supply["nearest_station_distance_norm"] + lsoa_supply["bus_stops_density_norm"]) / n_supply

# %%
lsoa_supply
# Out:
#       n_lsoa   lsoa21cd        lsoa21nm  \
# 0          0  E01004901     Bolton 028E
# 1          1  E01005001       Bury 012B
# 2          2  E01004840     Bolton 012A
# 3          3  E01005006       Bury 012D
# 4          4  E01004773     Bolton 003D
# ...      ...        ...             ...
# 1697    1697  E01006410      Wigan 020E
# 1698    1698  E01006400      Wigan 021D
# 1699    1699  E01006331      Wigan 031D
# 1700    1700  E01006397      Wigan 011C
# 1701    1701  E01005866  Stockport 006C
#
#                                                geometry  area_sqkm  \
# 0     POLYGON ((366003.09300000034 406666.6879999991...   0.354363
# 1     POLYGON ((375480.34800000023 408593.1229999997...   0.238302
# 2     POLYGON ((367374.7810000004 411954.5940000005,...   4.181101
# 3     POLYGON ((377212.6880000001 410849.5, 377231.9...   1.772635
# 4     POLYGON ((371776.55900000036 412463.2035000007...   0.266227
# ...                                                 ...        ...
# 1697  POLYGON ((357596.9539999999 403017.37549999915...   0.628715
# 1698  POLYGON ((356213.7599999998 403792.3969999999,...   0.569408
# 1699  POLYGON ((367336.96999999974 401009.4519999996...   0.596520
# 1700  POLYGON ((354859.3119999999 406046.90399999917...   0.147755
# 1701  POLYGON ((388072.36649999954 392494.4039999991...   0.288469
#
#       bus_stops_count  bus_stops_density  nearest_station_distance  \
# 0                   4          11.287876                583.787237
# 1                   4          16.785438               2682.823140
# 2                  25           5.979287               2153.166001
# 3                  26          14.667433               2828.181650
# 4                   9          33.805782               1467.288813
# ...               ...                ...                       ...
# 1697                8          12.724362               2090.861678
# 1698                1           1.756210                588.128763
# 1699                6          10.058336               3640.594673
# 1700                4          27.071827               1516.597364
# 1701               16          55.465277                255.325137
#
#       nearest_station_distance_norm  bus_stops_density_norm  pt_supply
# 0                          0.081805                0.030128   0.055966
# 1                          0.375938                0.044801   0.210370
# 2                          0.301719                0.015959   0.158839
# 3                          0.396307                0.039148   0.217727
# 4                          0.205608                0.090228   0.147918
# ...                             ...                     ...        ...
# 1697                       0.292988                0.033962   0.163475
# 1698                       0.082413                0.004687   0.043550
# 1699                       0.510149                0.026846   0.268497
# 1700                       0.212518                0.072255   0.142386
# 1701                       0.035778                0.148038   0.091908
#
# [1702 rows x 11 columns]

# %%
lsoa_supply.plot.scatter(x= "n_lsoa", y= "pt_supply")
# Out:
# <Axes: xlabel='n_lsoa', ylabel='pt_supply'>

# %% [markdown]
# ### LSOA Demand

# %%
lsoa_demand
# Out:
#        lsoa21cd        lsoa21nm  area_sqkm  Total  women_perc  elderly_pe  \
# 0     E01004901     Bolton 028E   0.354363   1773    5.922166   29.606439
# 1     E01005001       Bury 012B   0.238302   1228    4.885993   22.384853
# 2     E01004840     Bolton 012A   4.181101   1769    4.578858   30.275798
# 3     E01005006       Bury 012D   1.772635   2051    6.874695   25.688674
# 4     E01004773     Bolton 003D   0.266227   1985    7.103275   25.395631
# ...         ...             ...        ...    ...         ...         ...
# 1764  E01006410      Wigan 020E   0.628715   1261    4.758128   33.287718
# 1765  E01006400      Wigan 021D   0.569408   1982    6.004036   18.415945
# 1766  E01006331      Wigan 031D   0.596520   1501    3.997335   28.514146
# 1767  E01006397      Wigan 011C   0.147755   1058    7.088847   32.333539
# 1768  E01005866  Stockport 006C   0.288469   1648    6.492718   20.054170
#
#       children_p   pop_densit  dis_nc_per  deprived_p  \
# 0      15.172025  5003.350923    5.045278    6.856404
# 1      19.218241  5153.129520    2.828283    7.676768
# 2      19.106840   423.094327    7.756233    9.418283
# 3      20.234032  1157.034831    7.434944   10.532838
# 4      19.143577  7456.052936    8.974359    8.158508
# ...          ...          ...         ...         ...
# 1764   15.543220  2005.677534    5.617978    7.490637
# 1765   26.135217  3480.807917    2.057613    7.270233
# 1766   16.122585  2516.260480    3.125000    5.625000
# 1767   16.446125  7160.498266   17.636684   19.047619
# 1768   16.080097  5712.923579   12.342569   10.705290
#
#                                                geometry
# 0     POLYGON ((366003.093 406666.688, 366004.412 40...
# 1     POLYGON ((375480.348 408593.123, 375481.063 40...
# 2     POLYGON ((367374.781 411954.594, 367387.095 41...
# 3     POLYGON ((377212.688 410849.500, 377231.906 41...
# 4     POLYGON ((371776.559 412463.204, 371825.243 41...
# ...                                                 ...
# 1764  POLYGON ((357596.954 403017.375, 357616.740 40...
# 1765  POLYGON ((356213.760 403792.397, 356213.312 40...
# 1766  POLYGON ((367336.970 401009.452, 367340.657 40...
# 1767  POLYGON ((354859.312 406046.904, 354861.775 40...
# 1768  POLYGON ((388072.366 392494.404, 388070.000 39...
#
# [1769 rows x 11 columns]

# %%
## Rename column to make it easier to understand
lsoa_demand = lsoa_demand.rename(columns={"women_perc" : "women_percent", "elderly_pe" : "elderly_percent", "children_p" : "child_percent", "pop_densit" : "pop_dens", "disabled_n" : "dis_no_car", "deprived_p" : "deprived_percent"})
lsoa_demand
# Out:
#        lsoa21cd        lsoa21nm  area_sqkm  Total  women_percent  \
# 0     E01004901     Bolton 028E   0.354363   1773       5.922166
# 1     E01005001       Bury 012B   0.238302   1228       4.885993
# 2     E01004840     Bolton 012A   4.181101   1769       4.578858
# 3     E01005006       Bury 012D   1.772635   2051       6.874695
# 4     E01004773     Bolton 003D   0.266227   1985       7.103275
# ...         ...             ...        ...    ...            ...
# 1764  E01006410      Wigan 020E   0.628715   1261       4.758128
# 1765  E01006400      Wigan 021D   0.569408   1982       6.004036
# 1766  E01006331      Wigan 031D   0.596520   1501       3.997335
# 1767  E01006397      Wigan 011C   0.147755   1058       7.088847
# 1768  E01005866  Stockport 006C   0.288469   1648       6.492718
#
#       elderly_percent  child_percent     pop_dens  dis_nc_per  \
# 0           29.606439      15.172025  5003.350923    5.045278
# 1           22.384853      19.218241  5153.129520    2.828283
# 2           30.275798      19.106840   423.094327    7.756233
# 3           25.688674      20.234032  1157.034831    7.434944
# 4           25.395631      19.143577  7456.052936    8.974359
# ...               ...            ...          ...         ...
# 1764        33.287718      15.543220  2005.677534    5.617978
# 1765        18.415945      26.135217  3480.807917    2.057613
# 1766        28.514146      16.122585  2516.260480    3.125000
# 1767        32.333539      16.446125  7160.498266   17.636684
# 1768        20.054170      16.080097  5712.923579   12.342569
#
#       deprived_percent                                           geometry
# 0             6.856404  POLYGON ((366003.093 406666.688, 366004.412 40...
# 1             7.676768  POLYGON ((375480.348 408593.123, 375481.063 40...
# 2             9.418283  POLYGON ((367374.781 411954.594, 367387.095 41...
# 3            10.532838  POLYGON ((377212.688 410849.500, 377231.906 41...
# 4             8.158508  POLYGON ((371776.559 412463.204, 371825.243 41...
# ...                ...                                                ...
# 1764          7.490637  POLYGON ((357596.954 403017.375, 357616.740 40...
# 1765          7.270233  POLYGON ((356213.760 403792.397, 356213.312 40...
# 1766          5.625000  POLYGON ((367336.970 401009.452, 367340.657 40...
# 1767         19.047619  POLYGON ((354859.312 406046.904, 354861.775 40...
# 1768         10.705290  POLYGON ((388072.366 392494.404, 388070.000 39...
#
# [1769 rows x 11 columns]

# %%
## Calculate normalised value of each column

lsoa_demand["women_percent_norm"] = lsoa_demand["women_percent"] / lsoa_demand["women_percent"].max()

lsoa_demand["elderly_percent_norm"] = lsoa_demand["elderly_percent"] / lsoa_demand["elderly_percent"].max()

lsoa_demand["child_percent_norm"] = lsoa_demand["child_percent"] / lsoa_demand["child_percent"].max()

lsoa_demand["pop_dens_norm"] = lsoa_demand["pop_dens"] / lsoa_demand["pop_dens"].max()

lsoa_demand["dis_nc_norm"] = lsoa_demand["dis_nc_per"] / lsoa_demand["dis_nc_per"].max()

lsoa_demand["deprived_percent_norm"] = lsoa_demand["deprived_percent"] / lsoa_demand["deprived_percent"].max()

# %%
## Calculate demand index

n_demand = 6  ## Number of variables considered in the index
lsoa_demand["pt_demand"] = (lsoa_demand["women_percent_norm"] + lsoa_demand["elderly_percent_norm"] + lsoa_demand["child_percent_norm"] + lsoa_demand["pop_dens_norm"] + lsoa_demand["dis_nc_norm"] + lsoa_demand["deprived_percent_norm"]) / n_demand

# %%
lsoa_demand
# Out:
#        lsoa21cd        lsoa21nm  area_sqkm  Total  women_percent  \
# 0     E01004901     Bolton 028E   0.354363   1773       5.922166
# 1     E01005001       Bury 012B   0.238302   1228       4.885993
# 2     E01004840     Bolton 012A   4.181101   1769       4.578858
# 3     E01005006       Bury 012D   1.772635   2051       6.874695
# 4     E01004773     Bolton 003D   0.266227   1985       7.103275
# ...         ...             ...        ...    ...            ...
# 1764  E01006410      Wigan 020E   0.628715   1261       4.758128
# 1765  E01006400      Wigan 021D   0.569408   1982       6.004036
# 1766  E01006331      Wigan 031D   0.596520   1501       3.997335
# 1767  E01006397      Wigan 011C   0.147755   1058       7.088847
# 1768  E01005866  Stockport 006C   0.288469   1648       6.492718
#
#       elderly_percent  child_percent     pop_dens  dis_nc_per  \
# 0           29.606439      15.172025  5003.350923    5.045278
# 1           22.384853      19.218241  5153.129520    2.828283
# 2           30.275798      19.106840   423.094327    7.756233
# 3           25.688674      20.234032  1157.034831    7.434944
# 4           25.395631      19.143577  7456.052936    8.974359
# ...               ...            ...          ...         ...
# 1764        33.287718      15.543220  2005.677534    5.617978
# 1765        18.415945      26.135217  3480.807917    2.057613
# 1766        28.514146      16.122585  2516.260480    3.125000
# 1767        32.333539      16.446125  7160.498266   17.636684
# 1768        20.054170      16.080097  5712.923579   12.342569
#
#       deprived_percent                                           geometry  \
# 0             6.856404  POLYGON ((366003.093 406666.688, 366004.412 40...
# 1             7.676768  POLYGON ((375480.348 408593.123, 375481.063 40...
# 2             9.418283  POLYGON ((367374.781 411954.594, 367387.095 41...
# 3            10.532838  POLYGON ((377212.688 410849.500, 377231.906 41...
# 4             8.158508  POLYGON ((371776.559 412463.204, 371825.243 41...
# ...                ...                                                ...
# 1764          7.490637  POLYGON ((357596.954 403017.375, 357616.740 40...
# 1765          7.270233  POLYGON ((356213.760 403792.397, 356213.312 40...
# 1766          5.625000  POLYGON ((367336.970 401009.452, 367340.657 40...
# 1767         19.047619  POLYGON ((354859.312 406046.904, 354861.775 40...
# 1768         10.705290  POLYGON ((388072.366 392494.404, 388070.000 39...
#
#       women_percent_norm  elderly_percent_norm  child_percent_norm  \
# 0               0.121836              0.588550            0.268415
# 1               0.100519              0.444991            0.339998
# 2               0.094200              0.601856            0.338027
# 3               0.141433              0.510668            0.357969
# 4               0.146135              0.504843            0.338677
# ...                  ...                   ...                 ...
# 1764            0.097889              0.661731            0.274982
# 1765            0.123521              0.366093            0.462369
# 1766            0.082237              0.566836            0.285232
# 1767            0.145838              0.642762            0.290956
# 1768            0.133574              0.398659            0.284480
#
#       pop_dens_norm  dis_nc_norm  deprived_percent_norm  pt_demand
# 0      5.032479e-10     0.143360               0.189032   0.218532
# 1      5.183130e-10     0.080365               0.211649   0.196254
# 2      4.255575e-11     0.220391               0.259663   0.252356
# 3      1.163771e-10     0.211261               0.290391   0.251954
# 4      7.499460e-10     0.255003               0.224931   0.244932
# ...             ...          ...                    ...        ...
# 1764   2.017354e-10     0.159633               0.206518   0.233459
# 1765   3.501072e-10     0.058466               0.200441   0.201815
# 1766   2.530909e-10     0.088796               0.155082   0.196364
# 1767   7.202185e-10     0.501140               0.525145   0.350973
# 1768   5.746183e-10     0.350710               0.295146   0.243761
#
# [1769 rows x 18 columns]

# %%
plt.scatter(range(len(lsoa_demand)), lsoa_demand["pt_demand"])

# %% [markdown]
# ## Merge Supply and Demand

# %%
## Join supply demand dataframes
pt_supply_demand = pd.merge(lsoa_supply[["lsoa21cd", "nearest_station_distance_norm", "bus_stops_density_norm", "pt_supply"]], lsoa_demand[["lsoa21cd","women_percent_norm", "elderly_percent_norm", "child_percent_norm", "pop_dens_norm", "dis_nc_norm", "deprived_percent_norm", "pt_demand", "geometry"]], on="lsoa21cd", how="left")
pt_supply_demand
# Out:
#        lsoa21cd  nearest_station_distance_norm  bus_stops_density_norm  \
# 0     E01004901                       0.081805                0.030128
# 1     E01005001                       0.375938                0.044801
# 2     E01004840                       0.301719                0.015959
# 3     E01005006                       0.396307                0.039148
# 4     E01004773                       0.205608                0.090228
# ...         ...                            ...                     ...
# 1697  E01006410                       0.292988                0.033962
# 1698  E01006400                       0.082413                0.004687
# 1699  E01006331                       0.510149                0.026846
# 1700  E01006397                       0.212518                0.072255
# 1701  E01005866                       0.035778                0.148038
#
#       pt_supply  women_percent_norm  elderly_percent_norm  child_percent_norm  \
# 0      0.055966            0.121836              0.588550            0.268415
# 1      0.210370            0.100519              0.444991            0.339998
# 2      0.158839            0.094200              0.601856            0.338027
# 3      0.217727            0.141433              0.510668            0.357969
# 4      0.147918            0.146135              0.504843            0.338677
# ...         ...                 ...                   ...                 ...
# 1697   0.163475            0.097889              0.661731            0.274982
# 1698   0.043550            0.123521              0.366093            0.462369
# 1699   0.268497            0.082237              0.566836            0.285232
# 1700   0.142386            0.145838              0.642762            0.290956
# 1701   0.091908            0.133574              0.398659            0.284480
#
#       pop_dens_norm  dis_nc_norm  deprived_percent_norm  pt_demand  \
# 0      5.032479e-10     0.143360               0.189032   0.218532
# 1      5.183130e-10     0.080365               0.211649   0.196254
# 2      4.255575e-11     0.220391               0.259663   0.252356
# 3      1.163771e-10     0.211261               0.290391   0.251954
# 4      7.499460e-10     0.255003               0.224931   0.244932
# ...             ...          ...                    ...        ...
# 1697   2.017354e-10     0.159633               0.206518   0.233459
# 1698   3.501072e-10     0.058466               0.200441   0.201815
# 1699   2.530909e-10     0.088796               0.155082   0.196364
# 1700   7.202185e-10     0.501140               0.525145   0.350973
# 1701   5.746183e-10     0.350710               0.295146   0.243761
#
#                                                geometry
# 0     POLYGON ((366003.093 406666.688, 366004.412 40...
# 1     POLYGON ((375480.348 408593.123, 375481.063 40...
# 2     POLYGON ((367374.781 411954.594, 367387.095 41...
# 3     POLYGON ((377212.688 410849.500, 377231.906 41...
# 4     POLYGON ((371776.559 412463.204, 371825.243 41...
# ...                                                 ...
# 1697  POLYGON ((357596.954 403017.375, 357616.740 40...
# 1698  POLYGON ((356213.760 403792.397, 356213.312 40...
# 1699  POLYGON ((367336.970 401009.452, 367340.657 40...
# 1700  POLYGON ((354859.312 406046.904, 354861.775 40...
# 1701  POLYGON ((388072.366 392494.404, 388070.000 39...
#
# [1702 rows x 12 columns]

# %%
pt_supply_demand.columns
# Out:
# Index(['lsoa21cd', 'nearest_station_distance_norm', 'bus_stops_density_norm',
#        'pt_supply', 'women_percent_norm', 'elderly_percent_norm',
#        'child_percent_norm', 'pop_dens_norm', 'dis_nc_norm',
#        'deprived_percent_norm', 'pt_demand', 'geometry'],
#       dtype='object')

# %%
## Transform into gdf
pt_supply_demand = gpd.GeoDataFrame(pt_supply_demand, geometry="geometry")
pt_supply_demand
# Out:
#        lsoa21cd  nearest_station_distance_norm  bus_stops_density_norm  \
# 0     E01004901                       0.081805                0.030128
# 1     E01005001                       0.375938                0.044801
# 2     E01004840                       0.301719                0.015959
# 3     E01005006                       0.396307                0.039148
# 4     E01004773                       0.205608                0.090228
# ...         ...                            ...                     ...
# 1697  E01006410                       0.292988                0.033962
# 1698  E01006400                       0.082413                0.004687
# 1699  E01006331                       0.510149                0.026846
# 1700  E01006397                       0.212518                0.072255
# 1701  E01005866                       0.035778                0.148038
#
#       pt_supply  women_percent_norm  elderly_percent_norm  child_percent_norm  \
# 0      0.055966            0.121836              0.588550            0.268415
# 1      0.210370            0.100519              0.444991            0.339998
# 2      0.158839            0.094200              0.601856            0.338027
# 3      0.217727            0.141433              0.510668            0.357969
# 4      0.147918            0.146135              0.504843            0.338677
# ...         ...                 ...                   ...                 ...
# 1697   0.163475            0.097889              0.661731            0.274982
# 1698   0.043550            0.123521              0.366093            0.462369
# 1699   0.268497            0.082237              0.566836            0.285232
# 1700   0.142386            0.145838              0.642762            0.290956
# 1701   0.091908            0.133574              0.398659            0.284480
#
#       pop_dens_norm  dis_nc_norm  deprived_percent_norm  pt_demand  \
# 0      5.032479e-10     0.143360               0.189032   0.218532
# 1      5.183130e-10     0.080365               0.211649   0.196254
# 2      4.255575e-11     0.220391               0.259663   0.252356
# 3      1.163771e-10     0.211261               0.290391   0.251954
# 4      7.499460e-10     0.255003               0.224931   0.244932
# ...             ...          ...                    ...        ...
# 1697   2.017354e-10     0.159633               0.206518   0.233459
# 1698   3.501072e-10     0.058466               0.200441   0.201815
# 1699   2.530909e-10     0.088796               0.155082   0.196364
# 1700   7.202185e-10     0.501140               0.525145   0.350973
# 1701   5.746183e-10     0.350710               0.295146   0.243761
#
#                                                geometry
# 0     POLYGON ((366003.093 406666.688, 366004.412 40...
# 1     POLYGON ((375480.348 408593.123, 375481.063 40...
# 2     POLYGON ((367374.781 411954.594, 367387.095 41...
# 3     POLYGON ((377212.688 410849.500, 377231.906 41...
# 4     POLYGON ((371776.559 412463.204, 371825.243 41...
# ...                                                 ...
# 1697  POLYGON ((357596.954 403017.375, 357616.740 40...
# 1698  POLYGON ((356213.760 403792.397, 356213.312 40...
# 1699  POLYGON ((367336.970 401009.452, 367340.657 40...
# 1700  POLYGON ((354859.312 406046.904, 354861.775 40...
# 1701  POLYGON ((388072.366 392494.404, 388070.000 39...
#
# [1702 rows x 12 columns]

# %%
pt_supply_demand.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1702 entries, 0 to 1701
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   lsoa21cd                       1702 non-null   object
#  1   nearest_station_distance_norm  1702 non-null   float64
#  2   bus_stops_density_norm         1702 non-null   float64
#  3   pt_supply                      1702 non-null   float64
#  4   women_percent_norm             1702 non-null   float64
#  5   elderly_percent_norm           1702 non-null   float64
#  6   child_percent_norm             1702 non-null   float64
#  7   pop_dens_norm                  1702 non-null   float64
#  8   dis_nc_norm                    1702 non-null   float64
#  9   deprived_percent_norm          1702 non-null   float64
#  10  pt_demand                      1702 non-null   float64
#  11  geometry                       1702 non-null   geometry
# dtypes: float64(10), geometry(1), object(1)
# memory usage: 159.7+ KB

# %%
## Normalise pt_supply and pt_demand
pt_supply_demand["pt_supply_norm"] = pt_supply_demand["pt_supply"] / pt_supply_demand["pt_supply"].max()
pt_supply_demand["pt_demand_norm"] = pt_supply_demand["pt_demand"] / pt_supply_demand["pt_demand"].max()

pt_supply_demand
# Out:
#        lsoa21cd  nearest_station_distance_norm  bus_stops_density_norm  \
# 0     E01004901                       0.081805                0.030128
# 1     E01005001                       0.375938                0.044801
# 2     E01004840                       0.301719                0.015959
# 3     E01005006                       0.396307                0.039148
# 4     E01004773                       0.205608                0.090228
# ...         ...                            ...                     ...
# 1697  E01006410                       0.292988                0.033962
# 1698  E01006400                       0.082413                0.004687
# 1699  E01006331                       0.510149                0.026846
# 1700  E01006397                       0.212518                0.072255
# 1701  E01005866                       0.035778                0.148038
#
#       pt_supply  women_percent_norm  elderly_percent_norm  child_percent_norm  \
# 0      0.055966            0.121836              0.588550            0.268415
# 1      0.210370            0.100519              0.444991            0.339998
# 2      0.158839            0.094200              0.601856            0.338027
# 3      0.217727            0.141433              0.510668            0.357969
# 4      0.147918            0.146135              0.504843            0.338677
# ...         ...                 ...                   ...                 ...
# 1697   0.163475            0.097889              0.661731            0.274982
# 1698   0.043550            0.123521              0.366093            0.462369
# 1699   0.268497            0.082237              0.566836            0.285232
# 1700   0.142386            0.145838              0.642762            0.290956
# 1701   0.091908            0.133574              0.398659            0.284480
#
#       pop_dens_norm  dis_nc_norm  deprived_percent_norm  pt_demand  \
# 0      5.032479e-10     0.143360               0.189032   0.218532
# 1      5.183130e-10     0.080365               0.211649   0.196254
# 2      4.255575e-11     0.220391               0.259663   0.252356
# 3      1.163771e-10     0.211261               0.290391   0.251954
# 4      7.499460e-10     0.255003               0.224931   0.244932
# ...             ...          ...                    ...        ...
# 1697   2.017354e-10     0.159633               0.206518   0.233459
# 1698   3.501072e-10     0.058466               0.200441   0.201815
# 1699   2.530909e-10     0.088796               0.155082   0.196364
# 1700   7.202185e-10     0.501140               0.525145   0.350973
# 1701   5.746183e-10     0.350710               0.295146   0.243761
#
#                                                geometry  pt_supply_norm  \
# 0     POLYGON ((366003.093 406666.688, 366004.412 40...        0.107035
# 1     POLYGON ((375480.348 408593.123, 375481.063 40...        0.402329
# 2     POLYGON ((367374.781 411954.594, 367387.095 41...        0.303777
# 3     POLYGON ((377212.688 410849.500, 377231.906 41...        0.416401
# 4     POLYGON ((371776.559 412463.204, 371825.243 41...        0.282891
# ...                                                 ...             ...
# 1697  POLYGON ((357596.954 403017.375, 357616.740 40...        0.312643
# 1698  POLYGON ((356213.760 403792.397, 356213.312 40...        0.083289
# 1699  POLYGON ((367336.970 401009.452, 367340.657 40...        0.513497
# 1700  POLYGON ((354859.312 406046.904, 354861.775 40...        0.272312
# 1701  POLYGON ((388072.366 392494.404, 388070.000 39...        0.175773
#
#       pt_demand_norm
# 0           0.378957
# 1           0.340324
# 2           0.437612
# 3           0.436914
# 4           0.424737
# ...              ...
# 1697        0.404841
# 1698        0.349968
# 1699        0.340515
# 1700        0.608624
# 1701        0.422708
#
# [1702 rows x 14 columns]

# %%
## Create new column for calculating the difference

pt_supply_demand["demand_supply_differences"] = pt_supply_demand["pt_demand_norm"] - pt_supply_demand["pt_supply_norm"]
pt_supply_demand
# Out:
#        lsoa21cd  nearest_station_distance_norm  bus_stops_density_norm  \
# 0     E01004901                       0.081805                0.030128
# 1     E01005001                       0.375938                0.044801
# 2     E01004840                       0.301719                0.015959
# 3     E01005006                       0.396307                0.039148
# 4     E01004773                       0.205608                0.090228
# ...         ...                            ...                     ...
# 1697  E01006410                       0.292988                0.033962
# 1698  E01006400                       0.082413                0.004687
# 1699  E01006331                       0.510149                0.026846
# 1700  E01006397                       0.212518                0.072255
# 1701  E01005866                       0.035778                0.148038
#
#       pt_supply  women_percent_norm  elderly_percent_norm  child_percent_norm  \
# 0      0.055966            0.121836              0.588550            0.268415
# 1      0.210370            0.100519              0.444991            0.339998
# 2      0.158839            0.094200              0.601856            0.338027
# 3      0.217727            0.141433              0.510668            0.357969
# 4      0.147918            0.146135              0.504843            0.338677
# ...         ...                 ...                   ...                 ...
# 1697   0.163475            0.097889              0.661731            0.274982
# 1698   0.043550            0.123521              0.366093            0.462369
# 1699   0.268497            0.082237              0.566836            0.285232
# 1700   0.142386            0.145838              0.642762            0.290956
# 1701   0.091908            0.133574              0.398659            0.284480
#
#       pop_dens_norm  dis_nc_norm  deprived_percent_norm  pt_demand  \
# 0      5.032479e-10     0.143360               0.189032   0.218532
# 1      5.183130e-10     0.080365               0.211649   0.196254
# 2      4.255575e-11     0.220391               0.259663   0.252356
# 3      1.163771e-10     0.211261               0.290391   0.251954
# 4      7.499460e-10     0.255003               0.224931   0.244932
# ...             ...          ...                    ...        ...
# 1697   2.017354e-10     0.159633               0.206518   0.233459
# 1698   3.501072e-10     0.058466               0.200441   0.201815
# 1699   2.530909e-10     0.088796               0.155082   0.196364
# 1700   7.202185e-10     0.501140               0.525145   0.350973
# 1701   5.746183e-10     0.350710               0.295146   0.243761
#
#                                                geometry  pt_supply_norm  \
# 0     POLYGON ((366003.093 406666.688, 366004.412 40...        0.107035
# 1     POLYGON ((375480.348 408593.123, 375481.063 40...        0.402329
# 2     POLYGON ((367374.781 411954.594, 367387.095 41...        0.303777
# 3     POLYGON ((377212.688 410849.500, 377231.906 41...        0.416401
# 4     POLYGON ((371776.559 412463.204, 371825.243 41...        0.282891
# ...                                                 ...             ...
# 1697  POLYGON ((357596.954 403017.375, 357616.740 40...        0.312643
# 1698  POLYGON ((356213.760 403792.397, 356213.312 40...        0.083289
# 1699  POLYGON ((367336.970 401009.452, 367340.657 40...        0.513497
# 1700  POLYGON ((354859.312 406046.904, 354861.775 40...        0.272312
# 1701  POLYGON ((388072.366 392494.404, 388070.000 39...        0.175773
#
#       pt_demand_norm  demand_supply_differences
# 0           0.378957                   0.271923
# 1           0.340324                  -0.062004
# 2           0.437612                   0.133835
# 3           0.436914                   0.020513
# 4           0.424737                   0.141845
# ...              ...                        ...
# 1697        0.404841                   0.092198
# 1698        0.349968                   0.266679
# 1699        0.340515                  -0.172982
# 1700        0.608624                   0.336312
# 1701        0.422708                   0.246935
#
# [1702 rows x 15 columns]

# %%
## Create a column for diff_rank
## The higher the rank -> Need DRT

## Sort df by 'demand_supply_differences' in descending order
pt_supply_demand_sorted = pt_supply_demand.sort_values(by="demand_supply_differences", ascending=False)

## Create the 'rank' column
pt_supply_demand_sorted["diff_rank"] = range(1, len(pt_supply_demand_sorted) + 1)
pt_supply_demand_sorted
# Out:
#        lsoa21cd  nearest_station_distance_norm  bus_stops_density_norm  \
# 549   E01005610                       0.052838                0.079558
# 437   E01005754                       0.049804                0.065530
# 579   E01005210                       0.097718                0.208716
# 1454  E01005756                       0.021442                0.030377
# 1500  E01033949                       0.078052                0.077222
# ...         ...                            ...                     ...
# 426   E01005014                       0.935469                0.084649
# 1668  E01006347                       0.855281                0.151594
# 1659  E01006303                       1.000000                0.025927
# 1620  E01006302                       0.993466                0.016334
# 393   E01005016                       0.898331                0.112652
#
#       pt_supply  women_percent_norm  elderly_percent_norm  child_percent_norm  \
# 549    0.066198            0.787601              0.851961            0.195232
# 437    0.057667            0.167110              0.369347            0.418846
# 579    0.153217            0.854690              0.892292            0.163253
# 1454   0.025910            0.199149              0.334398            0.493663
# 1500   0.077637            0.236430              0.375917            0.376284
# ...         ...                 ...                   ...                 ...
# 426    0.510059            0.110607              0.677836            0.274645
# 1668   0.503437            0.094869              0.706653            0.307677
# 1659   0.512964            0.139693              0.613296            0.312330
# 1620   0.504900            0.152892              0.476264            0.345128
# 393    0.505492            0.118235              0.437834            0.299044
#
#       pop_dens_norm  dis_nc_norm  deprived_percent_norm  pt_demand  \
# 549    4.401267e-10     0.704446               0.769665   0.551484
# 437    4.532650e-10     0.979153               0.955373   0.481638
# 579    1.198325e-09     0.792819               0.756947   0.576667
# 1454   3.885693e-10     0.762277               0.792640   0.430354
# 1500   8.482976e-10     0.895783               1.000000   0.480736
# ...             ...          ...                    ...        ...
# 426    2.498275e-10     0.235853               0.196151   0.249182
# 1668   4.129547e-10     0.158103               0.115053   0.230393
# 1659   6.595245e-11     0.128974               0.234639   0.238155
# 1620   1.877421e-10     0.127994               0.266121   0.228066
# 393    3.924256e-10     0.187569               0.220716   0.210566
#
#                                                geometry  pt_supply_norm  \
# 549   POLYGON ((382382.589 399864.740, 382401.425 39...        0.126603
# 437   POLYGON ((390607.548 393101.450, 390611.942 39...        0.110287
# 579   POLYGON ((384153.632 396891.980, 384161.000 39...        0.293025
# 1454  POLYGON ((390827.813 393516.000, 390829.198 39...        0.049552
# 1500  POLYGON ((393444.877 399091.062, 393433.243 39...        0.148480
# ...                                                 ...             ...
# 426   POLYGON ((378829.600 417749.600, 378844.350 41...        0.975480
# 1668  POLYGON ((362235.020 397630.850, 362238.884 39...        0.962817
# 1659  POLYGON ((363350.507 399570.265, 363351.812 39...        0.981036
# 1620  POLYGON ((364308.400 397256.400, 364288.885 39...        0.965614
# 393   POLYGON ((378738.996 417171.726, 378769.188 41...        0.966746
#
#       pt_demand_norm  demand_supply_differences  diff_rank
# 549         0.956331                   0.829728          1
# 437         0.835211                   0.724923          2
# 579         1.000000                   0.706975          3
# 1454        0.746279                   0.696727          4
# 1500        0.833646                   0.685166          5
# ...              ...                        ...        ...
# 426         0.432107                  -0.543373       1698
# 1668        0.399525                  -0.563292       1699
# 1659        0.412986                  -0.568050       1700
# 1620        0.395491                  -0.570123       1701
# 393         0.365144                  -0.601602       1702
#
# [1702 rows x 16 columns]

# %% [markdown]
# ## Plot Supply and Demand

# %%
## Set up the plots
fig, axes = plt.subplots(2,1 , figsize=(25, 12))

## Plot Supply
pt_supply_demand_sorted.plot(ax=axes[0], column='pt_supply', legend=True, cmap='GnBu')
lsoa.plot(ax=axes[0], facecolor="white", alpha=0.5, edgecolor="none", linewidth=0.5)
axes[0].set_title('Supply Index')

## Plot Demand
pt_supply_demand_sorted.plot(ax=axes[1], column='pt_demand', legend=True, cmap='OrRd')
lsoa.plot(ax=axes[1], facecolor="white", alpha=0.5, edgecolor="none", linewidth=0.5)
axes[1].set_title('Demand Index')
# Out:
# Text(0.5, 1.0, 'Demand Index')

# %% [markdown]
# ## Plot Ranks

# %%
## Define the the number of lsoa for each percentage
top_3_percent = int((len(pt_supply_demand_sorted)) * 3/100)
top_5_percent = int((len(pt_supply_demand_sorted)) * 5/100)
top_10_percent = int((len(pt_supply_demand_sorted)) * 10/100)
top_15_percent = int((len(pt_supply_demand_sorted)) * 15/100)
top_25_percent = int((len(pt_supply_demand_sorted)) * 25/100)

## Filter the lsoa for each percentage
pt_supply_demand_3 = pt_supply_demand_sorted[pt_supply_demand_sorted["diff_rank"] <= top_3_percent]
pt_supply_demand_5 = pt_supply_demand_sorted[pt_supply_demand_sorted["diff_rank"] <= top_5_percent]
pt_supply_demand_10 = pt_supply_demand_sorted[pt_supply_demand_sorted["diff_rank"] <= top_10_percent]
pt_supply_demand_15 = pt_supply_demand_sorted[pt_supply_demand_sorted["diff_rank"] <= top_15_percent]
pt_supply_demand_25 = pt_supply_demand_sorted[pt_supply_demand_sorted["diff_rank"] <= top_25_percent]

# %%
## Set up the plots
fig, axes = plt.subplots(2, 2, figsize=(12, 6))

## Plot top 5% LSOAs
pt_supply_demand_5.plot(ax=axes[0,0], facecolor="red", legend=False)
lsoa_outline.plot(ax=axes[0,0], facecolor="w", alpha=0.5, edgecolor="black", linewidth=0.5)
axes[0,0].set_title('Top 5% LSOAs')

## Plot top 10% LSOAs
pt_supply_demand_10.plot(ax=axes[0,1], facecolor="sienna", legend=False)
lsoa_outline.plot(ax=axes[0,1], facecolor="w", alpha=0.5, edgecolor="black", linewidth=0.5)
axes[0,1].set_title('Top 10% LSOAs')

## Plot top 15% LSOAs
pt_supply_demand_15.plot(ax=axes[1,0], facecolor="peru", legend=False)
lsoa_outline.plot(ax=axes[1,0], facecolor="w", alpha=0.5, edgecolor="black", linewidth=0.5)
axes[1,0].set_title('Top 15% LSOAs')

## Plot top 25% LSOAs
pt_supply_demand_25.plot(ax=axes[1,1], facecolor="peachpuff", legend=False)
lsoa_outline.plot(ax=axes[1,1], facecolor="w", alpha=0.5, edgecolor="black", linewidth=0.5)
axes[1,1].set_title('Top 25% LSOAs')

## Display the plots
plt.tight_layout()
plt.show()

# %%
## Set up the plots
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

## Plot top 5% LSOAs
pt_supply_demand_25.plot(ax=ax, facecolor="lightblue", legend=False)
pt_supply_demand_15.plot(ax=ax, facecolor="c", legend=False)
pt_supply_demand_10.plot(ax=ax, facecolor="darkcyan", legend=False)
pt_supply_demand_5.plot(ax=ax, facecolor="darkslategray", legend=False)
lsoa_outline.plot(ax=ax, facecolor="w", alpha=0.5, edgecolor="black", linewidth=0.5)

## Display the plots
legend_elements = [
    Patch(facecolor='darkslategray', edgecolor='black', label='Top 5%'),
    Patch(facecolor='darkcyan', edgecolor='black', label='Top 10%'),
    Patch(facecolor='c', edgecolor='black', label='Top 15%'),
    Patch(facecolor='lightblue', edgecolor='black', label='Top 25%')
]
ax.legend(handles=legend_elements, loc='upper right')
ax.set_title('Supply-Demand Index Distribution')
plt.tight_layout()
plt.show()

# %%
## Export to shapefile

pt_supply_demand_3.to_file("Data/supply_demand_percentile/pt_supply_demand_3.shp")
pt_supply_demand_5.to_file("Data/supply_demand_percentile/pt_supply_demand_5.shp")
pt_supply_demand_10.to_file("Data/supply_demand_percentile/pt_supply_demand_10.shp")
pt_supply_demand_15.to_file("Data/supply_demand_percentile/pt_supply_demand_15.shp")
pt_supply_demand_25.to_file("Data/supply_demand_percentile/pt_supply_demand_25.shp")

pt_supply_demand_sorted.to_file("Data/supply_demand_sorted/pt_supply_demand_sorted.shp")
# Out:
# /tmp/ipykernel_305/1332979799.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pt_supply_demand_3.to_file("Data/supply_demand_percentile/pt_supply_demand_3.shp")
# /tmp/ipykernel_305/1332979799.py:4: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pt_supply_demand_5.to_file("Data/supply_demand_percentile/pt_supply_demand_5.shp")
# /tmp/ipykernel_305/1332979799.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pt_supply_demand_10.to_file("Data/supply_demand_percentile/pt_supply_demand_10.shp")
# /tmp/ipykernel_305/1332979799.py:6: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pt_supply_demand_15.to_file("Data/supply_demand_percentile/pt_supply_demand_15.shp")
# /tmp/ipykernel_305/1332979799.py:7: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pt_supply_demand_25.to_file("Data/supply_demand_percentile/pt_supply_demand_25.shp")
# /tmp/ipykernel_305/1332979799.py:9: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   pt_supply_demand_sorted.to_file("Data/supply_demand_sorted/pt_supply_demand_sorted.shp")
